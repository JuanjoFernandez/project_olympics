# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import create_engine, inspect, func
from config import password

# %%
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/project_olympics')
conn = engine.connect()

# %%
sports = 'df_sports.csv'
df_sports = pd.read_csv(sports, encoding="ISO-8859-1")
df_sports
# Out:
#        Unnamed: 0  year       sport       discipline               athlete  \
# 0               0  1896    Aquatics         Swimming         HAJOS, Alfred
# 1              97  1896  Gymnastics      Artistic G.   LOUNDRAS, Dimitrios
# 2              98  1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis
# 3              99  1896  Gymnastics      Artistic G.     BÃÂCKER, Konrad
# 4             100  1896  Gymnastics      Artistic G.        FLATOW, Alfred
# ...           ...   ...         ...              ...                   ...
# 29211       27847  2008  Basketball       Basketball       JIMENEZ, Carlos
# 29212       27846  2008  Basketball       Basketball            GASOL, Pau
# 29213       27845  2008  Basketball       Basketball           GASOL, Marc
# 29214       27858  2008  Basketball       Basketball        KUZINA, Marina
# 29215       29215  2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#       country_code gender                event   medal  medal_value
# ...

# %%
countries = 'countries.csv'
df_countries = pd.read_csv(countries, encoding="ISO-8859-1")
df_countries.head()
# Out:
#    Unnamed: 0      country country_code    gdp_1960    gdp_1964    gdp_1968  \
# 0           0  Afghanistan          AFG    0.000000   82.095307  129.108311
# 1           1      Albania          ALB    0.000000    0.000000    0.000000
# 2           2      Algeria          ALG  246.303751  238.043710  281.925786
# 3           3      Andorra          AND    0.000000    0.000000    0.000000
# 4           4       Angola          ANG    0.000000    0.000000    0.000000
#
#       gdp_1972     gdp_1976      gdp_1980     gdp_1984      gdp_1988  \
# 0   135.317228   197.445508    272.655510     0.000000      0.000000
# 1     0.000000     0.000000      0.000000   639.484736    652.774321
# 2   442.677623  1037.607160   2203.055461  2467.346082   2417.376189
# 3  4218.271599  7151.249909  12378.784511  7728.906695  14304.640595
# 4     0.000000     0.000000    711.409579   638.099007    792.833017
#
#        gdp_1992      gdp_1996      gdp_2000      gdp_2004      gdp_2008  \
# ...

# %%
merged_df = df_sports.merge(df_countries, how='left', on="country_code")
merged_df
# Out:
#        Unnamed: 0_x  year       sport       discipline               athlete  \
# 0                 0  1896    Aquatics         Swimming         HAJOS, Alfred
# 1                97  1896  Gymnastics      Artistic G.   LOUNDRAS, Dimitrios
# 2                98  1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis
# 3                99  1896  Gymnastics      Artistic G.     BÃÂCKER, Konrad
# 4               100  1896  Gymnastics      Artistic G.        FLATOW, Alfred
# ...             ...   ...         ...              ...                   ...
# 29211         27847  2008  Basketball       Basketball       JIMENEZ, Carlos
# 29212         27846  2008  Basketball       Basketball            GASOL, Pau
# 29213         27845  2008  Basketball       Basketball           GASOL, Marc
# 29214         27858  2008  Basketball       Basketball        KUZINA, Marina
# 29215         29215  2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
# ...

# %%
merged_df2= merged_df.loc[merged_df["year"] == 2008 ]

# %%
merged_df2
# Out:
#        Unnamed: 0_x  year       sport       discipline          athlete  \
# 27174         28534  2008      Hockey           Hockey    RIBAS, Xavier
# 27175         28532  2008      Hockey           Hockey   GARZA, Rodrigo
# 27176         28535  2008      Hockey           Hockey     SALA, Albert
# 27177         28533  2008      Hockey           Hockey       OLIVA, Roc
# 27178         28536  2008      Hockey           Hockey     SOJO, Victor
# ...             ...   ...         ...              ...              ...
# 29211         27847  2008  Basketball       Basketball  JIMENEZ, Carlos
# 29212         27846  2008  Basketball       Basketball       GASOL, Pau
# 29213         27845  2008  Basketball       Basketball      GASOL, Marc
# 29214         27858  2008  Basketball       Basketball   KUZINA, Marina
# 29215         29215  2008   Wrestling  Wrestling Gre-R   BAROEV, Khasan
#
#       country_code gender       event   medal  medal_value  ...   gdp_1984  \
# ...

# %%
merged_df3  = merged_df2[["year", "sport", "athlete", "country_code", "gender", "medal_value", "latitude", "longitude", "gdp_2008"]]
merged_df3.dropna (inplace=True)
# Out:
# /Users/alejandrocruz/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_df3
# Out:
#        year       sport          athlete country_code gender  medal_value  \
# 27174  2008      Hockey    RIBAS, Xavier          ESP    Men            2
# 27175  2008      Hockey   GARZA, Rodrigo          ESP    Men            2
# 27176  2008      Hockey     SALA, Albert          ESP    Men            2
# 27177  2008      Hockey       OLIVA, Roc          ESP    Men            2
# 27178  2008      Hockey     SOJO, Victor          ESP    Men            2
# ...     ...         ...              ...          ...    ...          ...
# 29211  2008  Basketball  JIMENEZ, Carlos          ESP    Men            2
# 29212  2008  Basketball       GASOL, Pau          ESP    Men            2
# 29213  2008  Basketball      GASOL, Marc          ESP    Men            2
# 29214  2008  Basketball   KUZINA, Marina          RUS  Women            1
# 29215  2008   Wrestling   BAROEV, Khasan          RUS    Men            2
#
#         latitude   longitude      gdp_2008
# ...

# %%
merged_df3.to_json(orient='index')
# Out:
# '{"27174":{"year":2008,"sport":"Hockey","athlete":"RIBAS, Xavier","country_code":"ESP","gender":"Men","medal_value":2,"latitude":40.463667,"longitude":-3.74922,"gdp_2008":35510.7222312701},"27175":{"year":2008,"sport":"Hockey","athlete":"GARZA, Rodrigo","country_code":"ESP","gender":"Men","medal_value":2,"latitude":40.463667,"longitude":-3.74922,"gdp_2008":35510.7222312701},"27176":{"year":2008,"sport":"Hockey","athlete":"SALA, Albert","country_code":"ESP","gender":"Men","medal_value":2,"latitude":40.463667,"longitude":-3.74922,"gdp_2008":35510.7222312701},"27177":{"year":2008,"sport":"Hockey","athlete":"OLIVA, Roc","country_code":"ESP","gender":"Men","medal_value":2,"latitude":40.463667,"longitude":-3.74922,"gdp_2008":35510.7222312701},"27178":{"year":2008,"sport":"Hockey","athlete":"SOJO, Victor","country_code":"ESP","gender":"Men","medal_value":2,"latitude":40.463667,"longitude":-3.74922,"gdp_2008":35510.7222312701},"27179":{"year":2008,"sport":"Hockey","athlete":"GARCIA, Agustina
# ...

# %%
merged_df.to_sql(name= 'geodata', con=engine, if_exists='append', index= False)
