# %%
import pandas as pd
import numpy as np
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
from sqlalchemy import create_engine, inspect, func
#from config import password

# %%
#engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/project_olympics')
#conn = engine.connect()

# %%
# CSV location 
summer = 'SummerOlympicMedals.csv'

# %%
#Selecting columns, Renaming 
df_summer = pd.read_csv(summer, encoding="ISO-8859-1")
df_summer.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
#Reading CSV, Selecting columns, Renaming 
df_summer = df_summer[["Edition", "Sport", "Discipline", "Athlete", "NOC", "Gender", "Event", "Medal"]]

# %%
df_summer=df_summer.rename(columns={"Edition":"year", "Sport":"sport", "Discipline":"discipline","Athlete": "athlete","NOC":"country_code","Gender":"gender", "Event":"event", "Medal":"medal"})
df_summer
# Out:
#        year      sport       discipline               athlete country_code  \
# 0      1896   Aquatics         Swimming         HAJOS, Alfred          HUN
# 1      1896   Aquatics         Swimming      HERSCHMANN, Otto          AUT
# 2      1896   Aquatics         Swimming     DRIVAS, Dimitrios          GRE
# 3      1896   Aquatics         Swimming    MALOKINIS, Ioannis          GRE
# 4      1896   Aquatics         Swimming    CHASAPIS, Spiridon          GRE
# ...     ...        ...              ...                   ...          ...
# 29211  2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko          GER
# 29212  2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas          LTU
# 29213  2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri          ARM
# 29214  2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain          CUB
# 29215  2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan          RUS
#
#       gender                       event   medal
# 0        Men              100m freestyle    Gold
# 1        Men              100m freestyle  Silver
# 2        Men  100m freestyle for sailors  Bronze
# 3        Men  100m freestyle for sailors    Gold
# 4        Men  100m freestyle for sailors  Silver
# ...      ...                         ...     ...
# 29211    Men                   84 - 96kg  Silver
# 29212    Men                  96 - 120kg  Bronze
# 29213    Men                  96 - 120kg  Bronze
# 29214    Men                  96 - 120kg    Gold
# 29215    Men                  96 - 120kg  Silver
#
# [29216 rows x 8 columns]

# %%
df_summer_sorted = df_summer.sort_values("year")

df_summer_sorted["medal_value"] = 0 
df_summer_sorted
# Out:
#        year       sport       discipline               athlete country_code  \
# 0      1896    Aquatics         Swimming         HAJOS, Alfred          HUN
# 97     1896  Gymnastics      Artistic G.   LOUNDRAS, Dimitrios          GRE
# 98     1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis          GRE
# 99     1896  Gymnastics      Artistic G.       BÃCKER, Konrad          GER
# 100    1896  Gymnastics      Artistic G.        FLATOW, Alfred          GER
# ...     ...         ...              ...                   ...          ...
# 27847  2008  Basketball       Basketball       JIMENEZ, Carlos          ESP
# 27846  2008  Basketball       Basketball            GASOL, Pau          ESP
# 27845  2008  Basketball       Basketball           GASOL, Marc          ESP
# 27858  2008  Basketball       Basketball        KUZINA, Marina          RUS
# 29215  2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan          RUS
#
#       gender                event   medal  medal_value
# 0        Men       100m freestyle    Gold            0
# 97       Men  team, parallel bars  Bronze            0
# 98       Men  team, parallel bars  Bronze            0
# 99       Men  team, parallel bars    Gold            0
# 100      Men  team, parallel bars    Gold            0
# ...      ...                  ...     ...          ...
# 27847    Men           basketball  Silver            0
# 27846    Men           basketball  Silver            0
# 27845    Men           basketball  Silver            0
# 27858  Women           basketball  Bronze            0
# 29215    Men           96 - 120kg  Silver            0
#
# [29216 rows x 9 columns]

# %%
df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Bronze')]= 1
df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Silver')]= 2
df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Gold')]= 3
# Out:
# <ipython-input-8-bc0ea9e2410f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Bronze')]= 1
# <ipython-input-8-bc0ea9e2410f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Silver')]= 2
# <ipython-input-8-bc0ea9e2410f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_summer_sorted["medal_value"][df_summer_sorted["medal"].astype(str).str.contains('Gold')]= 3

# %%
df_sports = df_summer_sorted
df_sports
# Out:
#        year       sport       discipline               athlete country_code  \
# 0      1896    Aquatics         Swimming         HAJOS, Alfred          HUN
# 97     1896  Gymnastics      Artistic G.   LOUNDRAS, Dimitrios          GRE
# 98     1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis          GRE
# 99     1896  Gymnastics      Artistic G.       BÃCKER, Konrad          GER
# 100    1896  Gymnastics      Artistic G.        FLATOW, Alfred          GER
# ...     ...         ...              ...                   ...          ...
# 27847  2008  Basketball       Basketball       JIMENEZ, Carlos          ESP
# 27846  2008  Basketball       Basketball            GASOL, Pau          ESP
# 27845  2008  Basketball       Basketball           GASOL, Marc          ESP
# 27858  2008  Basketball       Basketball        KUZINA, Marina          RUS
# 29215  2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan          RUS
#
#       gender                event   medal  medal_value
# 0        Men       100m freestyle    Gold            3
# 97       Men  team, parallel bars  Bronze            1
# 98       Men  team, parallel bars  Bronze            1
# 99       Men  team, parallel bars    Gold            3
# 100      Men  team, parallel bars    Gold            3
# ...      ...                  ...     ...          ...
# 27847    Men           basketball  Silver            2
# 27846    Men           basketball  Silver            2
# 27845    Men           basketball  Silver            2
# 27858  Women           basketball  Bronze            1
# 29215    Men           96 - 120kg  Silver            2
#
# [29216 rows x 9 columns]

# %%
df_sports = df_sports[["year", "country_code", "medal_value"]]
df_sports
# Out:
#        year country_code  medal_value
# 0      1896          HUN            3
# 97     1896          GRE            1
# 98     1896          GRE            1
# 99     1896          GER            3
# 100    1896          GER            3
# ...     ...          ...          ...
# 27847  2008          ESP            2
# 27846  2008          ESP            2
# 27845  2008          ESP            2
# 27858  2008          RUS            1
# 29215  2008          RUS            2
#
# [29216 rows x 3 columns]

# %%
df_sports2 = df_sports.groupby(["year","country_code"])["medal_value"].sum()

# %%
df_sports2
# Out:
# year  country_code
# 1896  AUS               6
#       AUT              10
#       DEN              10
#       FRA              25
#       GBR              14
#                      ...
# 2008  USA             674
#       UZB              10
#       VEN               1
#       VIE               2
#       ZIM               9
# Name: medal_value, Length: 1072, dtype: int64

# %%
result = df_sports2.to_json(orient="table")
parsed = json.loads(result)
json.dumps(parsed)
# Out:
# '{"schema": {"fields": [{"name": "year", "type": "integer"}, {"name": "country_code", "type": "string"}, {"name": "medal_value", "type": "integer"}], "primaryKey": ["year", "country_code"], "pandas_version": "0.20.0"}, "data": [{"year": 1896, "country_code": "AUS", "medal_value": 6}, {"year": 1896, "country_code": "AUT", "medal_value": 10}, {"year": 1896, "country_code": "DEN", "medal_value": 10}, {"year": 1896, "country_code": "FRA", "medal_value": 25}, {"year": 1896, "country_code": "GBR", "medal_value": 14}, {"year": 1896, "country_code": "GER", "medal_value": 90}, {"year": 1896, "country_code": "GRE", "medal_value": 92}, {"year": 1896, "country_code": "HUN", "medal_value": 11}, {"year": 1896, "country_code": "SUI", "medal_value": 7}, {"year": 1896, "country_code": "USA", "medal_value": 49}, {"year": 1896, "country_code": "ZZX", "medal_value": 12}, {"year": 1900, "country_code": "AUS", "medal_value": 9}, {"year": 1900, "country_code": "AUT", "medal_value": 9}, {"year": 1900, "country_code": "BEL", "medal_value": 68}, {"year": 1900, "country_code": "BOH", "medal_value": 3}, {"year": 1900, "country_code": "CAN", "medal_value": 4}, {"year": 1900, "country_code": "CUB", "medal_value": 5}, {"year": 1900, "country_code": "DEN", "medal_value": 11}, {"year": 1900, "country_code": "ESP", "medal_value": 6}, {"year": 1900, "country_code": "FRA", "medal_value": 363}, {"year": 1900, "country_code": "GBR", "medal_value": 194}, {"year": 1900, "country_code": "GER", "medal_value": 81}, {"year": 1900, "country_code": "HUN", "medal_value": 9}, {"year": 1900, "country_code": "IND", "medal_value": 4}, {"year": 1900, "country_code": "ITA", "medal_value": 10}, {"year": 1900, "country_code": "NED", "medal_value": 25}, {"year": 1900, "country_code": "NOR", "medal_value": 15}, {"year": 1900, "country_code": "SUI", "medal_value": 42}, {"year": 1900, "country_code": "SWE", "medal_value": 1}, {"year": 1900, "country_code": "USA", "medal_value": 123}, {"year": 1900, "country_code": "ZZX", "medal_value": 78}, {"year": 1904, "country_code": "AUT", "medal_value": 1}, {"year": 1904, "country_code": "CAN", "medal_value": 96}, {"year": 1904, "country_code": "CUB", "medal_value": 19}, {"year": 1904, "country_code": "GBR", "medal_value": 5}, {"year": 1904, "country_code": "GER", "medal_value": 25}, {"year": 1904, "country_code": "GRE", "medal_value": 4}, {"year": 1904, "country_code": "HUN", "medal_value": 9}, {"year": 1904, "country_code": "SUI", "medal_value": 4}, {"year": 1904, "country_code": "USA", "medal_value": 823}, {"year": 1904, "country_code": "ZZX", "medal_value": 19}, {"year": 1908, "country_code": "ANZ", "medal_value": 51}, {"year": 1908, "country_code": "AUT", "medal_value": 1}, {"year": 1908, "country_code": "BEL", "medal_value": 57}, {"year": 1908, "country_code": "BOH", "medal_value": 5}, {"year": 1908, "country_code": "CAN", "medal_value": 93}, {"year": 1908, "country_code": "DEN", "medal_value": 27}, {"year": 1908, "country_code": "FIN", "medal_value": 32}, {"year": 1908, "country_code": "FRA", "medal_value": 58}, {"year": 1908, "country_code": "GBR", "medal_value": 770}, {"year": 1908, "country_code": "GER", "medal_value": 41}, {"year": 1908, "country_code": "GRE", "medal_value": 6}, {"year": 1908, "country_code": "HUN", "medal_value": 37}, {"year": 1908, "country_code": "ITA", "medal_value": 16}, {"year": 1908, "country_code": "NED", "medal_value": 11}, {"year": 1908, "country_code": "NOR", "medal_value": 92}, {"year": 1908, "country_code": "RSA", "medal_value": 5}, {"year": 1908, "country_code": "RU1", "medal_value": 7}, {"year": 1908, "country_code": "SWE", "medal_value": 254}, {"year": 1908, "country_code": "USA", "medal_value": 145}, {"year": 1912, "country_code": "ANZ", "medal_value": 22}, {"year": 1912, "country_code": "AUT", "medal_value": 23}, {"year": 1912, "country_code": "BEL", "medal_value": 38}, {"year": 1912, "country_code": "CAN", "medal_value": 16}, {"year": 1912, "country_code": "DEN", "medal_value": 139}, {"year": 1912,  ...

# %%
df_sports2 = df_sports.groupby(["year","country_code"])["medal_value"].sum().reset_index()

# %%
df_sports2.head(100)
# Out:
#     year country_code  medal_value
# 0   1896          AUS            6
# 1   1896          AUT           10
# 2   1896          DEN           10
# 3   1896          FRA           25
# 4   1896          GBR           14
# ..   ...          ...          ...
# 95  1920          RSA           39
# 96  1920          SUI           43
# 97  1920          SWE          288
# 98  1920          TCH           10
# 99  1920          USA          458
#
# [100 rows x 3 columns]

# %%
df_sports3= df_sports2.loc[df_sports2["year"] > 1943 ]
df_sports3.head(100)
# Out:
#      year country_code  medal_value
# 218  1948          ARG           26
# 219  1948          AUS           29
# 220  1948          AUT            6
# 221  1948          BEL           24
# 222  1948          BRA           12
# ..    ...          ...          ...
# 313  1956          HUN          144
# 314  1956          IND           51
# 315  1956          IRI           11
# 316  1956          IRL            8
# 317  1956          ISL            2
#
# [100 rows x 3 columns]

# %%
import json

# %%
result = df_sports2.to_json(orient="table")
parsed = json.loads(result)
json.dumps(parsed,)
# Out:
# '{"schema": {"fields": [{"name": "index", "type": "integer"}, {"name": "year", "type": "integer"}, {"name": "country_code", "type": "string"}, {"name": "medal_value", "type": "integer"}], "primaryKey": ["index"], "pandas_version": "0.20.0"}, "data": [{"index": 0, "year": 1896, "country_code": "AUS", "medal_value": 6}, {"index": 1, "year": 1896, "country_code": "AUT", "medal_value": 10}, {"index": 2, "year": 1896, "country_code": "DEN", "medal_value": 10}, {"index": 3, "year": 1896, "country_code": "FRA", "medal_value": 25}, {"index": 4, "year": 1896, "country_code": "GBR", "medal_value": 14}, {"index": 5, "year": 1896, "country_code": "GER", "medal_value": 90}, {"index": 6, "year": 1896, "country_code": "GRE", "medal_value": 92}, {"index": 7, "year": 1896, "country_code": "HUN", "medal_value": 11}, {"index": 8, "year": 1896, "country_code": "SUI", "medal_value": 7}, {"index": 9, "year": 1896, "country_code": "USA", "medal_value": 49}, {"index": 10, "year": 1896, "country_code": "ZZX", "medal_value": 12}, {"index": 11, "year": 1900, "country_code": "AUS", "medal_value": 9}, {"index": 12, "year": 1900, "country_code": "AUT", "medal_value": 9}, {"index": 13, "year": 1900, "country_code": "BEL", "medal_value": 68}, {"index": 14, "year": 1900, "country_code": "BOH", "medal_value": 3}, {"index": 15, "year": 1900, "country_code": "CAN", "medal_value": 4}, {"index": 16, "year": 1900, "country_code": "CUB", "medal_value": 5}, {"index": 17, "year": 1900, "country_code": "DEN", "medal_value": 11}, {"index": 18, "year": 1900, "country_code": "ESP", "medal_value": 6}, {"index": 19, "year": 1900, "country_code": "FRA", "medal_value": 363}, {"index": 20, "year": 1900, "country_code": "GBR", "medal_value": 194}, {"index": 21, "year": 1900, "country_code": "GER", "medal_value": 81}, {"index": 22, "year": 1900, "country_code": "HUN", "medal_value": 9}, {"index": 23, "year": 1900, "country_code": "IND", "medal_value": 4}, {"index": 24, "year": 1900, "country_code": "ITA", "medal_value": 10}, {"index": 25, "year": 1900, "country_code": "NED", "medal_value": 25}, {"index": 26, "year": 1900, "country_code": "NOR", "medal_value": 15}, {"index": 27, "year": 1900, "country_code": "SUI", "medal_value": 42}, {"index": 28, "year": 1900, "country_code": "SWE", "medal_value": 1}, {"index": 29, "year": 1900, "country_code": "USA", "medal_value": 123}, {"index": 30, "year": 1900, "country_code": "ZZX", "medal_value": 78}, {"index": 31, "year": 1904, "country_code": "AUT", "medal_value": 1}, {"index": 32, "year": 1904, "country_code": "CAN", "medal_value": 96}, {"index": 33, "year": 1904, "country_code": "CUB", "medal_value": 19}, {"index": 34, "year": 1904, "country_code": "GBR", "medal_value": 5}, {"index": 35, "year": 1904, "country_code": "GER", "medal_value": 25}, {"index": 36, "year": 1904, "country_code": "GRE", "medal_value": 4}, {"index": 37, "year": 1904, "country_code": "HUN", "medal_value": 9}, {"index": 38, "year": 1904, "country_code": "SUI", "medal_value": 4}, {"index": 39, "year": 1904, "country_code": "USA", "medal_value": 823}, {"index": 40, "year": 1904, "country_code": "ZZX", "medal_value": 19}, {"index": 41, "year": 1908, "country_code": "ANZ", "medal_value": 51}, {"index": 42, "year": 1908, "country_code": "AUT", "medal_value": 1}, {"index": 43, "year": 1908, "country_code": "BEL", "medal_value": 57}, {"index": 44, "year": 1908, "country_code": "BOH", "medal_value": 5}, {"index": 45, "year": 1908, "country_code": "CAN", "medal_value": 93}, {"index": 46, "year": 1908, "country_code": "DEN", "medal_value": 27}, {"index": 47, "year": 1908, "country_code": "FIN", "medal_value": 32}, {"index": 48, "year": 1908, "country_code": "FRA", "medal_value": 58}, {"index": 49, "year": 1908, "country_code": "GBR", "medal_value": 770}, {"index": 50, "year": 1908, "country_code": "GER", "medal_value": 41}, {"index": 51, "year": 1908, "country_code": "GRE", "medal_value": 6}, {"index": 52, "year": 1908, "country_code": "HUN", "medal_value": 37}, {"index":  ...

# %%
df_barchart.to_csv('barchart7.csv', index = False)

# %%
df_sports.dtypes
# Out:
# year             int64
# country_code    object
# medal_value      int64
# dtype: object

# %%
# Sending to postrgress
df_sports.to_sql(name= 'sports', con=engine, if_exists='append', index= False)
